# %%
# %run configure.py
# %matplotlib inline
import matplotlib.pyplot as plt
from quantities import mV, nA
from hippounit import models, tests, capabilities

# %%
target_Ith = 0.6*nA
Ith_SD = 0.3*nA
target_Veq = -40.1*mV
Veq_SD = 3.4*mV

observation = {'mean_Ith':target_Ith,'Ith_std':Ith_SD, 'mean_Veq': target_Veq, 'Veq_std': Veq_SD}

# %%
show_plot = False
test = tests.DepolarizationBlockTest(observation, force_run=False, show_plot=show_plot)

# %%
model = models.Bianchi()

# %%
score = test.judge(model)
score.summarize()
if show_plot: 
    plt.show()
# Out:
# The figures are saved in the directory:  ./figs/depol_block/Bianchi/
# Ith (the current intensity for which the model exhibited the maximum number of APs): 0.0
# Veq (the equilibrium value during the depolarization block): 24.1028734394
# 0 <class 'numpy.int64'>
# The error of Veq in units of the experimental SD:  18.883198070405214 dimensionless
# The error of Ith in units of the experimental SD:  2.0 dimensionless
# === Model Bianchi (Bianchi) achieved score Z_Ith = -2.00, Z_Veq = 18.88 on test 'Depolarization block test (DepolarizationBlockTest)'. ===
