# %%
# %run configure.py
# %matplotlib inline
import matplotlib.pyplot as plt
from quantities import mV, nA
from hippounit import models, tests, capabilities

# %%
target_Ith = 0.6*nA
Ith_SD = 0.3*nA
target_Veq = -40.1*mV
Veq_SD = 3.4*mV

observation = {'mean_Ith':target_Ith,'Ith_std':Ith_SD, 'mean_Veq': target_Veq, 'Veq_std': Veq_SD}

# %%
show_plot=False
test = tests.DepolarizationBlockTest(observation, force_run=False, show_plot=show_plot)

# %%
model = models.Migliore()

# %%
score = test.judge(model)
score.summarize()
if show_plot: 
    plt.show()
# Out:
# The figures are saved in the directory:  ./figs/depol_block/Migliore/
# Ith (the current intensity for which the model exhibited the maximum number of APs):- running amplitude: 0.0
# - running amplitude: 0.15
# - running amplitude: 0.3
# - running amplitude: 0.45
# ('- running model', 'Migliore')('- running model', 'Migliore')('- running model', 'Migliore')('- running model', 'Migliore')
#
#
#
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 0.05
#  0.2
#  0.35
#  0.5
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 0.1
#  0.25
#  0.4
#  0.55
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 0.6
#  1.05
#  0.75
#  0.9
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 0.65
#  1.1
#  0.8
#  0.95
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 0.7
#  1.15
#  0.85
#  1.0
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# - running amplitude:- running amplitude:- running amplitude: 1.2
#  1.5
#  1.35
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# - running amplitude:- running amplitude:- running amplitude: 1.25
#  1.55
#  1.4
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# - running amplitude:- running amplitude:- running amplitude: 1.3
#  1.6
#  1.45
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
# ('- running model', 'Migliore')
#  0.9
# Veq (the equilibrium value during the depolarization block): -16.7205231846
# The error of Veq in units of the experimental SD:  6.87631671042247 dimensionless
# The error of Ith in units of the experimental SD:  1.0000000000000002 dimensionless
# === Model Migliore (Migliore) achieved score Z_Ith = 1.00, Z_Veq = 6.88 on test 'Depolarization block test (DepolarizationBlockTest)'. ===
