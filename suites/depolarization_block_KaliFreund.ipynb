# %%
# %run configure.py
# %matplotlib inline
import matplotlib.pyplot as plt
from quantities import mV, nA
from hippounit import models, tests, capabilities

# %%
target_Ith = 0.6*nA
Ith_SD = 0.3*nA
target_Veq = -40.1*mV
Veq_SD = 3.4*mV

observation = {'mean_Ith':target_Ith,'Ith_std':Ith_SD, 'mean_Veq': target_Veq, 'Veq_std': Veq_SD}

# %%
show_plot=False
test = tests.DepolarizationBlockTest(observation, force_run=False, show_plot=show_plot)

# %%
model = models.KaliFreund()

# %%
score = test.judge(model)
score.summarize()
if show_plot: 
    plt.show()
# Out:
# The figures are saved in the directory:  ./figs/depol_block/Kali/
# Ith (the current intensity for which the model exhibited the maximum number of APs):- running amplitude: 0.15
# - running amplitude: 0.0
# - running amplitude: 0.45
# - running amplitude: 0.3
# ('- running model', 'Kali')('- running model', 'Kali')('- running model', 'Kali')('- running model', 'Kali')
#
#
#
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 0.2
#  0.05
#  0.5
#  0.35
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 0.25
#  0.1
#  0.55
#  0.4
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 1.05
#  0.75
#  0.6
#  0.9
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 1.1
#  0.8
#  0.65
#  0.95
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# - running amplitude:- running amplitude:- running amplitude:- running amplitude: 1.15
#  0.85
#  0.7
#  1.0
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# - running amplitude:- running amplitude:- running amplitude: 1.5
#  1.35
#  1.2
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# - running amplitude:- running amplitude:- running amplitude: 1.55
#  1.4
#  1.25
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# - running amplitude:- running amplitude:- running amplitude: 1.6
#  1.45
#  1.3
# ('- running model', 'Kali')
# ('- running model', 'Kali')
# ('- running model', 'Kali')
#  0.0
# Veq (the equilibrium value during the depolarization block): -34.7613565874
# The error of Veq in units of the experimental SD:  1.5701892390074041 dimensionless
# The error of Ith in units of the experimental SD:  2.0 dimensionless
# === Model Kali (KaliFreund) achieved score Z_Ith = -2.00, Z_Veq = 1.57 on test 'Depolarization block test (DepolarizationBlockTest)'. ===
