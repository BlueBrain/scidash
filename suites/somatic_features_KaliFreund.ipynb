# %%
# %run configure.py
# %matplotlib inline
import matplotlib.pyplot as plt
from hippounit import models, tests, capabilities
import json
import collections

# %%
with open('../observations/stimfeat/PC_newfeat_No14112401_15012303-m990803_stimfeat.json') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

observation = config['features']

# %%
show_plot=True
test = tests.SomaticFeaturesTest(observation, force_run=False, show_plot=show_plot)

# %%
model = models.KaliFreund()

# %%
score = test.judge(model)
score.summarize()
if show_plot: 
    plt.show()
# Out:
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/efel/api.py:302: RuntimeWarning: Error while calculating feature AHP_depth:
# Feature [voltage_base_start_perc] is missing
#
# Feature [voltage_base_end_perc] is missing
#
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_values] is missing
#
#   RuntimeWarning)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/efel/api.py:302: RuntimeWarning: Error while calculating feature AP_duration_half_width:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [peak_voltage] is missing
# AP_amplitude: Error calculating peak_voltage
# Feature [AP_amplitude] is missing
#
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [peak_voltage] is missing
# AP_amplitude: Error calculating peak_voltage
# Feature [AP_amplitude] is missing
#
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
# Feature [AP_rise_indices] is missing
#
#   RuntimeWarning)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# The figures are saved in the directory:  ./figs/soma/Kali/
# === Model Kali (KaliFreund) achieved score Z_sum = nan on test 'Somatic features test (SomaticFeaturesTest)'. ===
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:94: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Users/rgerkin/Dropbox/python3/lib/python3.4/site-packages/numpy/core/_methods.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
